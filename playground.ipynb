# %%
import yfinance as yf
import pandas as pd

# %%
ticker = yf.Ticker("META")
number = ticker.info['enterpriseValue']
formatted_number = f"{number / 1000000:,.1f}"
formatted_number
# Out:
# '1,667,110.4'

# %%
ticker_df = ticker.income_stmt
ticker_df
# Out:
#                                                       2024-12-31  \
# Tax Effect Of Unusual Items                        -8.142000e+07
# Tax Rate For Calcs                                  1.180000e-01
# Normalized EBITDA                                   8.756600e+10
# Total Unusual Items                                -6.900000e+08
# Total Unusual Items Excluding Goodwill             -6.900000e+08
# Net Income From Continuing Operation Net Minori...  6.236000e+10
# Reconciled Depreciation                             1.549800e+10
# Reconciled Cost Of Revenue                          3.016100e+10
# EBITDA                                              8.687600e+10
# EBIT                                                7.137800e+10
# Net Interest Income                                 1.973000e+09
# Interest Expense                                    7.150000e+08
# Interest Income                                     2.517000e+09
# ...

# %%
ticker_df.iloc[2]
# Out:
# 2024-12-31    8.756600e+10
# 2023-12-31    5.941800e+10
# 2022-12-31    3.777100e+10
# 2021-12-31    5.541400e+10
# Name: Normalized EBITDA, dtype: float64

# %%
ticker_df.iloc[45]
# Out:
# 2024-12-31    1.645010e+11
# 2023-12-31    1.349020e+11
# 2022-12-31    1.166090e+11
# 2021-12-31    1.179290e+11
# Name: Total Revenue, dtype: float64

# %%
ticker_df.iloc[44]
# Out:
# 2024-12-31    3.016100e+10
# 2023-12-31    2.595900e+10
# 2022-12-31    2.524900e+10
# 2021-12-31    2.264900e+10
# Name: Cost Of Revenue, dtype: float64

# %%
ticker_df.iloc[43]
# Out:
# 2024-12-31    1.343400e+11
# 2023-12-31    1.089430e+11
# 2022-12-31    9.136000e+10
# 2021-12-31    9.528000e+10
# Name: Gross Profit, dtype: float64

# %%
ticker_df.iloc[37]
# Out:
# 2024-12-31    6.496000e+10
# 2023-12-31    6.219200e+10
# 2022-12-31    6.241600e+10
# 2021-12-31    4.852700e+10
# Name: Operating Expense, dtype: float64

# %%
ticker_q_df = ticker.quarterly_income_stmt
ticker_q_df
# Out:
#                                                       2025-09-30  \
# Tax Effect Of Unusual Items                         8.820000e+06
# Tax Rate For Calcs                                  2.100000e-01
# Normalized EBITDA                                   2.681100e+10
# Total Unusual Items                                 4.200000e+07
# Total Unusual Items Excluding Goodwill              4.200000e+07
# Net Income From Continuing Operation Net Minori...  2.709000e+09
# Reconciled Depreciation                             4.963000e+09
# Reconciled Cost Of Revenue                          9.206000e+09
# EBITDA                                              2.685300e+10
# EBIT                                                2.189000e+10
# Net Interest Income                                 1.086000e+09
# Interest Expense                                    2.270000e+08
# Interest Income                                     3.590000e+08
# ...
